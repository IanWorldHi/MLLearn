# %% [markdown]
# <a href="https://colab.research.google.com/github/IanWorldHi/MLLearn/blob/main/pytorcher/torchGPURealCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Remember to terminate GPU sessions. Running cmds in terminal is prefixed by "!"

# %%
import torch
#typical best practice is to write device agnostic code, checking if CPU or GPU and running on wtv there is
deviceVar = "cuda" if torch.cuda.is_available() else "cpu"
#numpy does NOT leverage GPU
torch.cuda.is_available(), torch.cuda.device_count(), deviceVar #checks if GPU avaliable & how many
# Out:
# (True, 1, 'cuda')

# %%
# !nvidia-smi
# Out:
# Wed Mar 18 14:12:16 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
ten = torch.tensor([[1]])
print(ten, ten.device)
tenGPU = ten.to(deviceVar)
tenGPU, tenGPU.cpu()
# Out:
# tensor([[1]]) cpu
# (tensor([[1]], device='cuda:0'), tensor([[1]]))
