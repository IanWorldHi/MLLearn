# %% [markdown]
# <a href="https://colab.research.google.com/github/IanWorldHi/MLLearn/blob/main/pytorcher/torchCustDatasetCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Custom Datasets Notes:
# - Data preperation, transform data, data loading functions, torch.utils.data.Dataset, data augmentation, loss curves - under/overfitting
# -

# %%
import torch
from torch import nn
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import requests
import zipfile
from pathlib import Path

# %% [markdown]
# Built in python func for walking thru directory and seeing its output ~useful for datasets

# %%
import os
def walk_through_dir(dir_path):
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %% [markdown]
# torchvision.transforms
# loading image data and turning into tensors:
