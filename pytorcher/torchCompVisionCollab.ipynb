# %% [markdown]
# <a href="https://colab.research.google.com/github/IanWorldHi/MLLearn/blob/main/torchCompVisionCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Computer Vision with Pytorch and some specific nn types for it (will be skipping/skimming some parts of the learning/tutorial bc of overlap and bc I don't need it for my proj)

# %% [markdown]
# Pytorch Modules for Computer Vision:
# - torchvision:
# - torchvision.data: many examples of datasets
# - torchvision.models: commonly used model architectures
# - torchvision.transforms: image transformations
# - torch.utils.data.Dataset: base dataset class in Pytorch
# - torch.utils.data.Dataloader: Python iterator over database

# %% [markdown]
# Baseline Model: Simplest model imaginable that you slowly improve on ig
#
# Datasets and Dataloaders:
# - Dataloader turns large dataset into batches - model is trained batch at a time

# %%
from torch.utils.data import DataLoader
batch_size = 32
training_dataloader = DataLoader(training_data, batch_size=batch_size, shuffle=True) #Shuffles at start of each epoch to reduce outside factors & sequential-like patterns

# %% [markdown]
# Notes:
# - Using nn.flatten to turn height width into one metric bc nn's work better with feature vectors - ud also be doing 1 pizel per input so w*h
# - Convolutiona Neural Networks (CNN) are good for visual data finding
